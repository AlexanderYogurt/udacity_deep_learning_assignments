# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
# each word is correspoding to a number:
# dictionary: word -> number; reverse_dictionary: number -> word
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
# have a glance at the dictionary
print(dictionary.items()[0:10])
print(reverse_dictionary.items()[0:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.760779
# Nearest to there: dropouts, proleptic, personage, spurious, householder, mccormick, iucn, homeomorphism,
# Nearest to called: ann, libretto, freyr, farther, notable, geyser, luncheon, melanchthon,
# Nearest to on: incarcerated, advocate, jumps, hans, imperfection, coffin, unexplained, offenders,
# Nearest to united: dionysius, jenny, vulgar, blackmore, arcology, midway, loci, fitted,
# Nearest to only: libertarianism, ears, eugenio, historicism, visualizing, coy, sturluson, correlatives,
# Nearest to so: populous, electrode, laborious, bern, eyewitness, entertainments, fulani, gallantry,
# Nearest to for: switchable, inconvenience, degeneracy, applets, dogg, tiglath, stallion, wrapping,
# Nearest to has: zamboanga, unconventional, geoffroy, keyboardist, coconuts, retaliatory, klister, vestry,
# Nearest to have: sunsets, breisgau, cove, circuits, gpc, chords, straddle, metabolites,
# Nearest to no: commencement, mounting, abaye, dxm, demoted, retaliatory, categories, resonator,
# Nearest to american: claudel, proposals, bofors, letting, flowers, gallico, razzie, ics,
# Nearest to many: using, deflect, curie, tegucigalpa, haploid, nikos, originally, octet,
# Nearest to four: cowpox, edvac, forth, haiku, reloading, guillermo, rectangles, uzbekistan,
# Nearest to can: maids, karel, trademark, ting, carboniferous, musicology, dull, copacabana,
# Nearest to six: simulate, octavio, dit, kendall, enactments, explored, hunchback, universiti,
# Nearest to their: bigotry, delany, uniforms, ancients, converse, brainwashed, systemic, cedes,
# Average loss at step 2000: 4.364608
# Average loss at step 4000: 3.865332
# Average loss at step 6000: 3.784998
# Average loss at step 8000: 3.684616
# Average loss at step 10000: 3.615921
# Nearest to there: it, generally, he, they, not, personage, postcard, gunfight,
# Nearest to called: farther, chaffee, homework, virtualization, freyr, farrar, salvator, courtyards,
# Nearest to on: in, at, by, bayes, jumps, greenberg, bowel, slings,
# Nearest to united: dionysius, midway, maths, following, extremities, fitted, bridgeport, turkmenistan,
# Nearest to only: ears, libertarianism, visualizing, enix, haznawi, coy, telecoms, paranormal,
# Nearest to so: bentine, entertainments, eyewitness, ili, bubba, expressing, nicholson, numeral,
# Nearest to for: switchable, loved, within, with, labarum, from, rosicrucians, imitative,
# Nearest to has: had, was, have, is, keyboardist, fay, gendarmerie, frites,
# Nearest to have: had, be, has, circuits, are, laughter, davey, habitats,
# Nearest to no: commencement, vegetarianism, asking, bm, it, destructive, mounting, emanate,
# Nearest to american: ottomans, silk, russian, bofors, psychoactive, giambattista, letting, bulwark,
# Nearest to many: some, several, curie, usaaf, chukotka, heads, deflect, agouti,
# Nearest to four: six, three, eight, seven, five, two, nine, zero,
# Nearest to can: could, would, may, will, should, unites, unclean, deepest,
# Nearest to six: eight, seven, four, three, nine, five, zero, two,
# Nearest to their: his, the, its, deportations, prespa, her, yardbirds, some,
# Average loss at step 12000: 3.609623
# Average loss at step 14000: 3.568448
# Average loss at step 16000: 3.409533
# Average loss at step 18000: 3.454751
# Average loss at step 20000: 3.538504
# Nearest to there: it, they, he, generally, which, still, slade, lex,
# Nearest to called: woodcut, rapp, farther, courtyards, cad, homework, barr, farrar,
# Nearest to on: in, at, upon, bayes, jer, productions, bowel, jumps,
# Nearest to united: dionysius, following, midway, clippers, maths, fitted, uu, opting,
# Nearest to only: excommunicated, enix, coy, ears, libertarianism, again, paranormal, commodities,
# Nearest to so: ili, eyewitness, cuttings, bentine, entertainments, bubba, fulani, bern,
# Nearest to for: with, switchable, of, markers, at, to, infirmities, by,
# Nearest to has: had, was, have, is, whetstone, pianos, corman, merv,
# Nearest to have: had, has, be, were, are, glorify, sprite, farthest,
# Nearest to no: a, taliban, vegetarianism, alloys, arkham, emanate, commencement, diets,
# Nearest to american: russian, french, adjectival, british, letting, english, silk, psychoactive,
# Nearest to many: some, several, these, all, other, amplifier, usaaf, their,
# Nearest to four: seven, eight, six, three, five, two, nine, zero,
# Nearest to can: may, could, would, will, should, might, must, macintosh,
# Nearest to six: seven, eight, four, nine, five, three, two, zero,
# Nearest to their: his, its, the, her, some, several, deportations, serapeum,
# Average loss at step 22000: 3.501802
# Average loss at step 24000: 3.491480
# Average loss at step 26000: 3.481359
# Average loss at step 28000: 3.476510
# Average loss at step 30000: 3.503489
# Nearest to there: they, it, he, still, generally, now, probably, not,
# Nearest to called: woodcut, courtyards, notable, farrar, barr, van, rapp, farther,
# Nearest to on: in, upon, from, bayes, during, between, backbone, at,
# Nearest to united: dionysius, midway, following, clippers, uu, cambridge, houston, maths,
# Nearest to only: enix, labor, coy, subordination, again, about, ineffective, ears,
# Nearest to so: bentine, ili, beowulf, eyewitness, stabilised, protectorates, entertainments, too,
# Nearest to for: switchable, with, of, gand, laterally, from, when, markers,
# Nearest to has: had, have, is, was, whetstone, stats, corman, previously,
# Nearest to have: had, has, are, be, were, glorify, sprite, milliardo,
# Nearest to no: arkham, a, alloys, diets, dilute, accrington, cathedral, taliban,
# Nearest to american: english, russian, british, adjectival, german, australian, french, ottomans,
# Nearest to many: some, several, these, all, most, their, they, outlandish,
# Nearest to four: five, seven, eight, six, three, two, nine, zero,
# Nearest to can: could, may, would, will, should, cannot, must, might,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to their: his, its, the, her, some, these, many, any,
# Average loss at step 32000: 3.498583
# Average loss at step 34000: 3.494204
# Average loss at step 36000: 3.459198
# Average loss at step 38000: 3.301601
# Average loss at step 40000: 3.430317
# Nearest to there: it, they, he, now, still, often, generally, also,
# Nearest to called: woodcut, courtyards, van, rapp, farrar, barr, tove, cad,
# Nearest to on: upon, at, about, jumps, jer, in, during, xxxi,
# Nearest to united: midway, clippers, following, dionysius, houston, bridgeport, same, soviet,
# Nearest to only: commodities, darnley, again, excommunicated, hei, watering, watt, windward,
# Nearest to so: bentine, electrode, beowulf, entertainments, stabilised, fuss, then, ili,
# Nearest to for: switchable, sweetener, resale, salvatore, in, from, potential, gand,
# Nearest to has: had, have, was, is, cleves, clarinets, pianos, previously,
# Nearest to have: had, has, be, are, were, glorify, instruct, represent,
# Nearest to no: arkham, alloys, any, diets, parthians, dilute, a, taliban,
# Nearest to american: russian, english, british, adjectival, german, australian, french, ottomans,
# Nearest to many: some, several, these, various, each, their, kerenyi, most,
# Nearest to four: six, three, five, seven, eight, two, nine, one,
# Nearest to can: could, may, will, would, should, must, might, cannot,
# Nearest to six: five, seven, four, three, eight, nine, two, one,
# Nearest to their: its, his, her, the, several, some, these, any,
# Average loss at step 42000: 3.435505
# Average loss at step 44000: 3.455918
# Average loss at step 46000: 3.449324
# Average loss at step 48000: 3.356560
# Average loss at step 50000: 3.381662
# Nearest to there: they, it, now, he, who, generally, she, still,
# Nearest to called: woodcut, rapp, courtyards, glorantha, known, tove, ethnocentric, farrar,
# Nearest to on: upon, jer, in, jumps, about, carnivores, over, bayes,
# Nearest to united: midway, clippers, dionysius, following, houston, same, loci, bridgeport,
# Nearest to only: darnley, again, dachshunds, catering, commodities, enix, boy, not,
# Nearest to so: then, bentine, electrode, entertainments, ginette, purer, staggering, if,
# Nearest to for: while, switchable, concerning, goodyear, against, including, salvatore, by,
# Nearest to has: had, have, was, is, cleves, anarchistic, clarinets, having,
# Nearest to have: had, has, were, are, be, desks, refer, tends,
# Nearest to no: any, arkham, diets, alloys, indistinguishable, plaintext, epiphanes, a,
# Nearest to american: english, russian, british, adjectival, french, australian, ducal, oldest,
# Nearest to many: some, several, these, various, both, those, most, all,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to can: could, may, will, would, should, must, cannot, might,
# Nearest to six: eight, seven, nine, four, five, three, two, zero,
# Nearest to their: its, his, her, the, some, several, both, these,
# Average loss at step 52000: 3.437026
# Average loss at step 54000: 3.428828
# Average loss at step 56000: 3.436077
# Average loss at step 58000: 3.395713
# Average loss at step 60000: 3.396136
# Nearest to there: they, it, now, still, often, he, generally, this,
# Nearest to called: closeup, used, known, rapp, courtyards, woodcut, amphetamines, popularized,
# Nearest to on: upon, through, within, jer, in, gonzalo, about, bowel,
# Nearest to united: midway, following, clippers, dionysius, houston, soviet, same, kan,
# Nearest to only: hei, until, darnley, again, also, extolling, enix, dachshunds,
# Nearest to so: then, bentine, electrode, less, even, too, if, fuss,
# Nearest to for: switchable, including, of, after, assur, goodyear, while, potential,
# Nearest to has: had, have, was, is, cleves, previously, having, whetstone,
# Nearest to have: had, has, were, are, be, produce, include, andrewes,
# Nearest to no: any, arkham, diets, alloys, rarest, newspapers, plugged, emanate,
# Nearest to american: english, russian, british, adjectival, oldest, german, australian, ducal,
# Nearest to many: some, several, these, various, most, such, all, both,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to six: four, eight, five, nine, three, seven, zero, two,
# Nearest to their: its, his, her, the, your, my, these, them,
# Average loss at step 62000: 3.234769
# Average loss at step 64000: 3.257416
# Average loss at step 66000: 3.405101
# Average loss at step 68000: 3.390659
# Average loss at step 70000: 3.362542
# Nearest to there: it, they, now, he, still, often, we, generally,
# Nearest to called: known, popularized, word, considered, used, amphetamines, rde, closeup,
# Nearest to on: upon, through, in, within, about, jer, under, into,
# Nearest to united: midway, following, same, dionysius, clippers, houston, ter, bridgeport,
# Nearest to only: worthies, yet, hei, both, watt, still, every, paramagnetic,
# Nearest to so: then, bentine, fuss, hereafter, cuttings, thus, too, therefore,
# Nearest to for: switchable, while, in, to, including, sweetener, if, against,
# Nearest to has: had, have, was, is, cleves, clo, since, makes,
# Nearest to have: had, has, are, were, produce, be, having, include,
# Nearest to no: any, there, little, lighted, alloys, arkham, emanate, diets,
# Nearest to american: english, british, oldest, italian, warring, russian, german, ducal,
# Nearest to many: some, several, most, various, these, all, numerous, both,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to can: could, may, would, will, cannot, should, must, might,
# Nearest to six: eight, seven, four, five, three, nine, two, zero,
# Nearest to their: its, his, her, the, your, some, these, serapeum,
# Average loss at step 72000: 3.374167
# Average loss at step 74000: 3.346193
# Average loss at step 76000: 3.317938
# Average loss at step 78000: 3.352393
# Average loss at step 80000: 3.375630
# Nearest to there: it, they, he, now, she, still, we, generally,
# Nearest to called: known, considered, used, closeup, referred, word, rde, amphetamines,
# Nearest to on: upon, through, in, within, ministerial, gonzalo, during, at,
# Nearest to united: midway, houston, clippers, ter, following, dionysius, bridgeport, schottenheimer,
# Nearest to only: worthies, watt, contract, reference, always, freyja, hei, commodities,
# Nearest to so: bentine, existentialism, then, zebra, before, staggering, if, electrode,
# Nearest to for: including, switchable, sweetener, against, playwrights, marne, faro, mz,
# Nearest to has: had, have, was, is, cleves, since, clo, whetstone,
# Nearest to have: had, has, are, be, include, were, having, produce,
# Nearest to no: little, any, lighted, meconium, arkham, epiphanes, faiths, rarest,
# Nearest to american: british, german, irish, russian, australian, english, european, italian,
# Nearest to many: some, several, these, various, most, numerous, both, all,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to can: could, may, would, will, must, cannot, should, might,
# Nearest to six: seven, five, four, eight, three, nine, two, zero,
# Nearest to their: its, his, her, your, the, our, my, serapeum,
# Average loss at step 82000: 3.410948
# Average loss at step 84000: 3.414851
# Average loss at step 86000: 3.389686
# Average loss at step 88000: 3.351368
# Average loss at step 90000: 3.362277
# Nearest to there: it, they, he, now, still, she, we, generally,
# Nearest to called: used, known, considered, referred, rde, popularized, capping, word,
# Nearest to on: upon, at, under, in, within, through, paratime, ministerial,
# Nearest to united: following, houston, midway, same, clippers, ter, dionysius, census,
# Nearest to only: no, hei, every, ns, not, even, always, permission,
# Nearest to so: existentialism, then, too, before, zebra, bentine, driving, entertainments,
# Nearest to for: including, of, goodyear, marne, paglia, while, without, switchable,
# Nearest to has: had, have, is, was, since, cleves, having, makes,
# Nearest to have: had, has, were, are, be, having, desks, glorify,
# Nearest to no: any, little, only, arkham, emanate, lighted, nothing, juventus,
# Nearest to american: british, european, italian, russian, irish, warring, australian, german,
# Nearest to many: some, several, these, various, most, numerous, all, few,
# Nearest to four: five, seven, eight, six, three, two, nine, one,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to their: its, his, her, your, our, my, the, serapeum,
# Average loss at step 92000: 3.396413
# Average loss at step 94000: 3.252908
# Average loss at step 96000: 3.360199
# Average loss at step 98000: 3.237167
# Average loss at step 100000: 3.360133
# Nearest to there: they, he, now, it, we, still, generally, often,
# Nearest to called: used, referred, known, rde, word, named, there, capping,
# Nearest to on: upon, within, through, at, in, jer, during, ministerial,
# Nearest to united: houston, same, clippers, following, midway, cline, ter, census,
# Nearest to only: hei, every, not, no, consecutive, within, never, tractable,
# Nearest to so: bentine, too, then, thus, existentialism, therefore, falsified, fuss,
# Nearest to for: including, before, salvatore, after, when, goodyear, ecd, against,
# Nearest to has: had, have, is, was, since, cleves, recently, anarchistic,
# Nearest to have: had, has, were, are, be, having, contain, adhering,
# Nearest to no: little, any, arkham, only, rarest, epiphanes, routine, nothing,
# Nearest to american: british, italian, russian, canadian, english, adjectival, australian, robert,
# Nearest to many: some, several, these, various, numerous, all, those, few,
# Nearest to four: six, seven, five, eight, three, two, nine, zero,
# Nearest to can: could, may, must, will, should, would, cannot, might,
# Nearest to six: seven, four, five, eight, nine, three, two, zero,
# Nearest to their: its, his, her, your, the, our, my, these,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
